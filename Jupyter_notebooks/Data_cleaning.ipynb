# %%
import pandas as pd
import numpy as np
import re
import os
from feature_engine.outliers import Winsorizer
from sklearn.model_selection import train_test_split

# %%
PROJECT_DIR = r"C:\Users\yashg\OneDrive\Desktop\flight-sagemaker"
DATA_DIR = r"data"
file_name = r"flight_price.csv"

# %%
def get_data(file_name):
    flights_df = pd.read_csv(os.path.join(PROJECT_DIR, DATA_DIR,file_name)) 
    return flights_df

flights_df = get_data(file_name)

# %%
flights_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
flights_df.shape
# Out:
# (10683, 11)

# %%
flights_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
flights_df.columns.to_list()
# Out:
# ['Airline',
#  'Date_of_Journey',
#  'Source',
#  'Destination',
#  'Route',
#  'Dep_Time',
#  'Arrival_Time',
#  'Duration',
#  'Total_Stops',
#  'Additional_Info',
#  'Price']

# %%
flights_df.columns = [i.lower() for i in flights_df.columns.to_list()]

# %%
flights_df.columns
# Out:
# Index(['airline', 'date_of_journey', 'source', 'destination', 'route',
#        'dep_time', 'arrival_time', 'duration', 'total_stops',
#        'additional_info', 'price'],
#       dtype='object')

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# #### Now lets focus on Null and Duplicate values

# %%
flights_df.isnull().sum()
# Out:
# airline            0
# date_of_journey    0
# source             0
# destination        0
# route              1
# dep_time           0
# arrival_time       0
# duration           0
# total_stops        1
# additional_info    0
# price              0
# dtype: int64

# %%
## Null_values

flights_df[flights_df.isnull().any(axis=1)]
# Out:
#         airline date_of_journey source destination route dep_time  \
# 9039  Air India       6/05/2019  Delhi      Cochin   NaN    09:45
#
#       arrival_time duration total_stops additional_info  price
# 9039  09:25 07 May  23h 40m         NaN         No info   7480

# %%
flights_df.dropna(axis=0, inplace=True)

# %%
flights_df.isnull().sum()
# Out:
# airline            0
# date_of_journey    0
# source             0
# destination        0
# route              0
# dep_time           0
# arrival_time       0
# duration           0
# total_stops        0
# additional_info    0
# price              0
# dtype: int64

# %%
flights_df.head()
# Out:
#        airline date_of_journey    source destination                  route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   dep_time  arrival_time duration total_stops additional_info  price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
## Duplicate rows

flights_df[flights_df.duplicated(keep=False)].sort_values(["airline", "date_of_journey", "source", "destination"])
# Out:
#         airline date_of_journey    source destination                  route  \
# 6321  Air India      01/03/2019  Banglore   New Delhi  BLR → BOM → AMD → DEL
# 9848  Air India      01/03/2019  Banglore   New Delhi  BLR → BOM → AMD → DEL
# 572   Air India      03/03/2019  Banglore   New Delhi              BLR → DEL
# 8168  Air India      03/03/2019  Banglore   New Delhi              BLR → DEL
# 1495  Air India       1/04/2019   Kolkata    Banglore  CCU → DEL → COK → BLR
# ...         ...             ...       ...         ...                    ...
# 2692   SpiceJet      24/03/2019  Banglore   New Delhi              BLR → DEL
# 2870   SpiceJet      24/03/2019  Banglore   New Delhi              BLR → DEL
# 3711   SpiceJet      24/03/2019  Banglore   New Delhi              BLR → DEL
# 2634    Vistara      24/03/2019  Banglore   New Delhi              BLR → DEL
# 5470    Vistara      24/03/2019  Banglore   New Delhi              BLR → DEL
#
#      dep_time  arrival_time duration total_stops  \
# 6321    08:50  23:55 02 Mar   39h 5m     2 stops
# 9848    08:50  23:55 02 Mar   39h 5m     2 stops
# 572     21:10         23:55   2h 45m    non-stop
# 8168    21:10         23:55   2h 45m    non-stop
# 1495    10:00  01:20 02 Apr  15h 20m     2 stops
# ...       ...           ...      ...         ...
# 2692    05:45         08:35   2h 50m    non-stop
# 2870    05:45         08:35   2h 50m    non-stop
# 3711    20:30         23:20   2h 50m    non-stop
# 2634    11:30         14:10   2h 40m    non-stop
# 5470    11:30         14:10   2h 40m    non-stop
#
#                    additional_info  price
# 6321                       No info  17135
# 9848                       No info  17135
# 572                        No info   7591
# 8168                       No info   7591
# 1495                       No info  10408
# ...                            ...    ...
# 2692  No check-in baggage included   4273
# 2870  No check-in baggage included   4273
# 3711  No check-in baggage included   3873
# 2634                       No info   5403
# 5470                       No info   5403
#
# [415 rows x 11 columns]

# %%
flights_df.drop_duplicates(inplace=True)

# %%
flights_df
# Out:
#            airline date_of_journey    source destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        route dep_time  arrival_time duration total_stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       additional_info  price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10462 rows x 11 columns]

# %% [markdown]
# #### Airline column clean

# %%
flights_df["airline"].value_counts(normalize=True)
# Out:
# airline
# Jet Airways                          0.353661
# IndiGo                               0.195278
# Air India                            0.161919
# Multiple carriers                    0.114318
# SpiceJet                             0.077901
# Vistara                              0.045689
# Air Asia                             0.030491
# GoAir                                0.018543
# Multiple carriers Premium economy    0.001243
# Jet Airways Business                 0.000574
# Vistara Premium economy              0.000287
# Trujet                               0.000096
# Name: proportion, dtype: float64

# %%
flights_df.groupby("airline")["price"].max()
# Out:
# airline
# Air Asia                             13774
# Air India                            31945
# GoAir                                22794
# IndiGo                               22153
# Jet Airways                          54826
# Jet Airways Business                 79512
# Multiple carriers                    36983
# Multiple carriers Premium economy    14629
# SpiceJet                             23267
# Trujet                                4140
# Vistara                              21730
# Vistara Premium economy              11793
# Name: price, dtype: int64

# %%
flights_df.groupby("airline")["price"].min()
# Out:
# airline
# Air Asia                              3383
# Air India                             2050
# GoAir                                 3398
# IndiGo                                2227
# Jet Airways                           1840
# Jet Airways Business                 46490
# Multiple carriers                     5797
# Multiple carriers Premium economy     9845
# SpiceJet                              1759
# Trujet                                4140
# Vistara                               3687
# Vistara Premium economy               5969
# Name: price, dtype: int64

# %%
# Using vectorized operations with str.replace
flights_df["airline"] = flights_df["airline"].str.replace(" Premium economy", "", regex=False)
flights_df["airline"] = flights_df["airline"].str.replace(" Business", "", regex=False)

# %%
flights_df[flights_df["price"] > 50000]
# Out:
#                     airline date_of_journey    source destination  \
# 657    Jet Airways Business      01/03/2019  Banglore   New Delhi
# 1478            Jet Airways      18/03/2019  Banglore   New Delhi
# 2618            Jet Airways      18/03/2019  Banglore   New Delhi
# 2924   Jet Airways Business      01/03/2019  Banglore   New Delhi
# 5372   Jet Airways Business      01/03/2019  Banglore   New Delhi
# 5439            Jet Airways      01/03/2019  Banglore   New Delhi
# 9715   Jet Airways Business       6/03/2019     Delhi      Cochin
# 10364  Jet Airways Business      01/03/2019  Banglore   New Delhi
#
#                        route dep_time  arrival_time duration total_stops  \
# 657          BLR → BOM → DEL    05:45         10:45       5h      1 stop
# 1478         BLR → BOM → DEL    18:40  00:45 16 Mar    6h 5m      1 stop
# 2618         BLR → BOM → DEL    22:50  05:05 16 Mar   6h 15m      1 stop
# 2924         BLR → BOM → DEL    05:45         11:25   5h 40m      1 stop
# 5372         BLR → BOM → DEL    05:45         12:25   6h 40m      1 stop
# 5439         BLR → BOM → DEL    16:55         23:00    6h 5m      1 stop
# 9715   DEL → ATQ → BOM → COK    20:05  04:25 07 Mar   8h 20m     2 stops
# 10364        BLR → MAA → DEL    09:45         14:25   4h 40m      1 stop
#
#       additional_info  price
# 657           No info  52229
# 1478          No info  54826
# 2618          No info  54826
# 2924   Business class  79512
# 5372   Business class  62427
# 5439          No info  54826
# 9715          No info  52285
# 10364  Business class  57209

# %% [markdown]
# #### Datetime cloumns

# %%
flights_df[["date_of_journey", "dep_time", "arrival_time", "duration"]]
# Out:
#       date_of_journey dep_time  arrival_time duration
# 0          24/03/2019    22:20  01:10 22 Mar   2h 50m
# 1           1/05/2019    05:50         13:15   7h 25m
# 2           9/06/2019    09:25  04:25 10 Jun      19h
# 3          12/05/2019    18:05         23:30   5h 25m
# 4          01/03/2019    16:50         21:35   4h 45m
# ...               ...      ...           ...      ...
# 10678       9/04/2019    19:55         22:25   2h 30m
# 10679      27/04/2019    20:45         23:20   2h 35m
# 10680      27/04/2019    08:20         11:20       3h
# 10681      01/03/2019    11:30         14:10   2h 40m
# 10682       9/05/2019    10:55         19:15   8h 20m
#
# [10462 rows x 4 columns]

# %%
# Date of journey
flights_df["date_of_journey"] = pd.to_datetime(flights_df["date_of_journey"], format= "%d/%m/%Y")
flights_df.head()
# Out:
#        airline date_of_journey    source destination                  route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-05-12   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-03-01  Banglore   New Delhi        BLR → NAG → DEL
#
#   dep_time  arrival_time duration total_stops additional_info  price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
flights_df.sort_values("date_of_journey", ascending=True, inplace=True)

# %%
# Assuming dep_time is in "HH:MM" format
flights_df["dep_time"] =  pd.to_datetime(flights_df["dep_time"], format='%H:%M').dt.time
flights_df.head()
# Out:
#           airline date_of_journey    source destination  \
# 8957  Jet Airways      2019-03-01  Banglore   New Delhi
# 7137       IndiGo      2019-03-01  Banglore   New Delhi
# 1353    Air India      2019-03-01  Banglore   New Delhi
# 8940    Air India      2019-03-01  Banglore   New Delhi
# 8937       IndiGo      2019-03-01  Banglore   New Delhi
#
#                       route  dep_time  arrival_time duration total_stops  \
# 8957        BLR → BOM → DEL  08:55:00  05:05 02 Mar  20h 10m      1 stop
# 7137              BLR → DEL  21:20:00  00:15 02 Mar   2h 55m    non-stop
# 1353  BLR → BOM → IDR → DEL  06:45:00  11:10 02 Mar  28h 25m     2 stops
# 8940              BLR → DEL  21:10:00         23:55   2h 45m    non-stop
# 8937              BLR → DEL  13:00:00         15:50   2h 50m    non-stop
#
#      additional_info  price
# 8957  1 Long layover  26890
# 7137         No info  12649
# 1353         No info  20999
# 8940         No info  25703
# 8937         No info  19685

# %%
# Assuming arrival_time is in "HH:MM" format

flights_df["arrival_time"]  = pd.to_datetime(flights_df["arrival_time"].str.split(" ", expand=True)[0]).dt.time
flights_df.head()
# Out:
# C:\Users\yashg\AppData\Local\Temp\ipykernel_25724\2792553305.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   flights_df["arrival_time"]  = pd.to_datetime(flights_df["arrival_time"].str.split(" ", expand=True)[0]).dt.time
#           airline date_of_journey    source destination  \
# 8957  Jet Airways      2019-03-01  Banglore   New Delhi
# 7137       IndiGo      2019-03-01  Banglore   New Delhi
# 1353    Air India      2019-03-01  Banglore   New Delhi
# 8940    Air India      2019-03-01  Banglore   New Delhi
# 8937       IndiGo      2019-03-01  Banglore   New Delhi
#
#                       route  dep_time arrival_time duration total_stops  \
# 8957        BLR → BOM → DEL  08:55:00     05:05:00  20h 10m      1 stop
# 7137              BLR → DEL  21:20:00     00:15:00   2h 55m    non-stop
# 1353  BLR → BOM → IDR → DEL  06:45:00     11:10:00  28h 25m     2 stops
# 8940              BLR → DEL  21:10:00     23:55:00   2h 45m    non-stop
# 8937              BLR → DEL  13:00:00     15:50:00   2h 50m    non-stop
#
#      additional_info  price
# 8957  1 Long layover  26890
# 7137         No info  12649
# 1353         No info  20999
# 8940         No info  25703
# 8937         No info  19685

# %%
## Fixing duration

# %%
flights_df["duration"].str.split(" ", expand=True)
# Out:
#          0     1
# 8957   20h   10m
# 7137    2h   55m
# 1353   28h   25m
# 8940    2h   45m
# 8937    2h   50m
# ...    ...   ...
# 5740    8h  None
# 10367   1h   30m
# 1986    2h   25m
# 6089   30h   45m
# 1218   26h   25m
#
# [10462 rows x 2 columns]

# %%
flights_df.duration.loc[lambda ser: ~ser.str.contains("m")].unique()
# Out:
# array(['20h', '13h', '5h', '27h', '3h', '9h', '26h', '7h', '14h', '47h',
#        '11h', '8h', '4h', '21h', '6h', '23h', '12h', '24h', '16h', '15h',
#        '25h', '10h', '22h', '38h', '30h', '34h', '19h', '18h', '28h'],
#       dtype=object)

# %%
flights_df.duration.loc[lambda ser: ~ser.str.contains("h")].unique()
# Out:
# array(['5m'], dtype=object)

# %%
flights_df.duration.loc[lambda ser: ~ser.str.contains("h")]
# Out:
# 6474    5m
# Name: duration, dtype: object

# %%
## lets drop 6474 column, becoz a flight can't have 5 minute duration

flights_df.drop(6474, inplace=True)

# %%
duration = flights_df["duration"].str.split(" ", expand=True).set_axis(["hour", "minute"], axis=1)

# %%
flights_df["duration_in_minute"] = duration["hour"].str.replace("h","").astype(int)*60 + duration["minute"].str.replace("m","").fillna(0).astype(int)

# %%
flights_df.drop("duration", axis=1, inplace=True)

# %%
flights_df.head()
# Out:
#           airline date_of_journey    source destination  \
# 8957  Jet Airways      2019-03-01  Banglore   New Delhi
# 7137       IndiGo      2019-03-01  Banglore   New Delhi
# 1353    Air India      2019-03-01  Banglore   New Delhi
# 8940    Air India      2019-03-01  Banglore   New Delhi
# 8937       IndiGo      2019-03-01  Banglore   New Delhi
#
#                       route  dep_time arrival_time total_stops  \
# 8957        BLR → BOM → DEL  08:55:00     05:05:00      1 stop
# 7137              BLR → DEL  21:20:00     00:15:00    non-stop
# 1353  BLR → BOM → IDR → DEL  06:45:00     11:10:00     2 stops
# 8940              BLR → DEL  21:10:00     23:55:00    non-stop
# 8937              BLR → DEL  13:00:00     15:50:00    non-stop
#
#      additional_info  price  duration_in_minute
# 8957  1 Long layover  26890                1210
# 7137         No info  12649                 175
# 1353         No info  20999                1705
# 8940         No info  25703                 165
# 8937         No info  19685                 170

# %% [markdown]
# #### source column

# %%
flights_df["source"].value_counts(normalize=True)
# Out:
# source
# Delhi       0.415352
# Kolkata     0.273396
# Banglore    0.208297
# Mumbai      0.066533
# Chennai     0.036421
# Name: proportion, dtype: float64

# %% [markdown]
# #### destination column

# %%
flights_df["destination"].value_counts(normalize=True)
# Out:
# destination
# Cochin       0.415352
# Banglore     0.273396
# Delhi        0.120925
# New Delhi    0.087372
# Hyderabad    0.066533
# Kolkata      0.036421
# Name: proportion, dtype: float64

# %%
flights_df["destination"] = flights_df["destination"].str.replace("New Delhi", "Delhi")

# %% [markdown]
# #### route

# %%
flights_df.head()
# Out:
#           airline date_of_journey    source destination  \
# 8957  Jet Airways      2019-03-01  Banglore       Delhi
# 7137       IndiGo      2019-03-01  Banglore       Delhi
# 1353    Air India      2019-03-01  Banglore       Delhi
# 8940    Air India      2019-03-01  Banglore       Delhi
# 8937       IndiGo      2019-03-01  Banglore       Delhi
#
#                       route  dep_time arrival_time total_stops  \
# 8957        BLR → BOM → DEL  08:55:00     05:05:00      1 stop
# 7137              BLR → DEL  21:20:00     00:15:00    non-stop
# 1353  BLR → BOM → IDR → DEL  06:45:00     11:10:00     2 stops
# 8940              BLR → DEL  21:10:00     23:55:00    non-stop
# 8937              BLR → DEL  13:00:00     15:50:00    non-stop
#
#      additional_info  price  duration_in_minute
# 8957  1 Long layover  26890                1210
# 7137         No info  12649                 175
# 1353         No info  20999                1705
# 8940         No info  25703                 165
# 8937         No info  19685                 170

# %% [markdown]
# #### total_stops

# %%
flights_df["total_stops"].value_counts(normalize=True)
# Out:
# total_stops
# 1 stop      0.537711
# non-stop    0.332186
# 2 stops     0.125896
# 3 stops     0.004111
# 4 stops     0.000096
# Name: proportion, dtype: float64

# %%
flights_df["total_stops"] = flights_df["total_stops"].str.split(" ", expand=True)[0].replace("non-stop", 0).astype(int)

# %%
flights_df["total_stops"].value_counts(normalize=True)
# Out:
# total_stops
# 1    0.537711
# 0    0.332186
# 2    0.125896
# 3    0.004111
# 4    0.000096
# Name: proportion, dtype: float64

# %% [markdown]
# #### additional_info

# %%
flights_df["additional_info"].value_counts(normalize=True)
# Out:
# additional_info
# No info                         0.782048
# In-flight meal not included     0.184112
# No check-in baggage included    0.030399
# 1 Long layover                  0.001816
# Change airports                 0.000669
# Business class                  0.000382
# No Info                         0.000287
# 1 Short layover                 0.000096
# Red-eye flight                  0.000096
# 2 Long layover                  0.000096
# Name: proportion, dtype: float64

# %%
## Optimized fucntion code
def clean_data(df):
    # Drop missing and duplicate rows
    df.dropna(inplace=True)
    df.drop_duplicates(inplace=True)
    df.columns = [i.lower() for i in df.columns.to_list()]


    # Using vectorized operations with str.replace
    df["airline"] = df["airline"].str.replace(" Premium economy", "", regex=False)
    df["airline"] = df["airline"].str.replace(" Business", "", regex=False)


    # Convert date and time columns
    df["date_of_journey"] = pd.to_datetime(df["date_of_journey"], format="%d/%m/%Y")
    df["dep_time"] = pd.to_datetime(df["dep_time"], format='%H:%M').dt.time
    df["arrival_time"] = pd.to_datetime(df["arrival_time"].str.split(" ", n=1).str[0], dayfirst=True, format="mixed").dt.time

    # Parse and convert 'duration' to minutes
    df.drop(6474, inplace=True)
    duration = df["duration"].str.split(" ", expand=True).set_axis(["hour", "minute"], axis=1)
    df["duration"] = duration["hour"].str.replace("h","").astype(int)*60 + duration["minute"].str.replace("m","").fillna(0).astype(int)

    # Standardize 'destination' column
    df["destination"] = df["destination"].replace("New Delhi", "Delhi")

    # Imouting numeric in Total stops
    df["total_stops"] = df["total_stops"].str.split(" ", expand=True)[0].replace("non-stop", 0).astype(int)

    df.drop(["route","additional_info"], axis=1, inplace=True)
    
    
    return df

# %%
flights = pd.read_csv("C:/Users/yashg/OneDrive/Desktop/flight-sagemaker/data/flight_price.csv")

# %%
flights_cleaned = clean_data(flights)

# %%
flights_cleaned.head()
# Out:
#        airline date_of_journey    source destination  dep_time arrival_time  \
# 0       IndiGo      2019-03-24  Banglore       Delhi  22:20:00     01:10:00
# 1    Air India      2019-05-01   Kolkata    Banglore  05:50:00     13:15:00
# 2  Jet Airways      2019-06-09     Delhi      Cochin  09:25:00     04:25:00
# 3       IndiGo      2019-05-12   Kolkata    Banglore  18:05:00     23:30:00
# 4       IndiGo      2019-03-01  Banglore       Delhi  16:50:00     21:35:00
#
#    duration  total_stops  price
# 0       170            0   3897
# 1       445            2   7662
# 2      1140            2  13882
# 3       325            1   6218
# 4       285            1  13302

# %%
flights_cleaned.shape
# Out:
# (10461, 9)

# %% [markdown]
# ## Split Data

# %%
X = flights_cleaned.drop("price", axis=1)
y = flights_cleaned["price"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=42, test_size=0.2)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train,y_train, random_state=42, test_size=0.2)

# %%
print("train data shape" , (X_train.shape , y_train.shape))
print("val data shape" , (X_val.shape , y_val.shape))
print("test data shape" , (X_test.shape , y_test.shape))
# Out:
# train data shape ((6694, 8), (6694,))
# val data shape ((1674, 8), (1674,))
# test data shape ((2093, 8), (2093,))

# %%
win = Winsorizer(capping_method="iqr", fold=1.5)
X_train["price"] = win.fit_transform(pd.DataFrame(y_train, columns = ["price"]))

# %%
def export_data_to_csv(X,y,name):
    X["price"]  = y
    file_name = f"{name}.csv"
    X.to_csv(os.path.join(PROJECT_DIR, DATA_DIR,file_name), index=False)
    return X.head()

# %%
## Trian dataset export
export_data_to_csv(X_train,y_train,"train")
# Out:
#           airline date_of_journey   source destination  dep_time arrival_time  \
# 3832  Jet Airways      2019-05-27    Delhi      Cochin  20:55:00     12:35:00
# 3095  Jet Airways      2019-06-12  Kolkata    Banglore  18:55:00     16:20:00
# 9717    Air India      2019-05-18    Delhi      Cochin  09:45:00     09:25:00
# 3262       IndiGo      2019-06-03   Mumbai   Hyderabad  21:20:00     22:50:00
# 6502  Jet Airways      2019-04-01   Mumbai   Hyderabad  02:55:00     04:20:00
#
#       duration  total_stops  price
# 3832       940            1  12898
# 3095      1285            1  13044
# 9717      1420            2  10975
# 3262        90            0   2227
# 6502        85            0   5678

# %%
## Test dataset export
export_data_to_csv(X_test,y_test,"test")
# Out:
#           airline date_of_journey    source destination  dep_time  \
# 2150  Jet Airways      2019-03-06  Banglore       Delhi  08:00:00
# 3784     SpiceJet      2019-06-06   Kolkata    Banglore  22:20:00
# 714        IndiGo      2019-03-18   Kolkata    Banglore  05:30:00
# 7558  Jet Airways      2019-03-24    Mumbai   Hyderabad  15:50:00
# 7413     SpiceJet      2019-04-27  Banglore       Delhi  09:30:00
#
#      arrival_time  duration  total_stops  price
# 2150     08:15:00      1455            1  17996
# 3784     00:40:00       140            0   3873
# 714      08:20:00       170            0   4462
# 7558     17:20:00        90            0   2228
# 7413     12:20:00       170            0   4991

# %%
## Val dataset export
export_data_to_csv(X_val,y_val,"val")
# Out:
#           airline date_of_journey    source destination  dep_time  \
# 4171  Jet Airways      2019-05-27     Delhi      Cochin  09:00:00
# 9069  Jet Airways      2019-05-24   Kolkata    Banglore  18:55:00
# 2010  Jet Airways      2019-03-18  Banglore       Delhi  21:25:00
# 5454     SpiceJet      2019-06-27   Chennai     Kolkata  17:45:00
# 6302     Air Asia      2019-05-15   Kolkata    Banglore  07:35:00
#
#      arrival_time  duration  total_stops  price
# 4171     19:00:00       600            1  10675
# 9069     10:05:00       910            1   8586
# 2010     09:30:00       725            1  13555
# 5454     20:05:00       140            0   3543
# 6302     19:25:00       710            1   5192
